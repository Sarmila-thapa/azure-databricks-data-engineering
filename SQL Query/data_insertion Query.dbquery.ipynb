-- %%
INSERT INTO sales_catalog.sales.orders
VALUES
(1, 'John', 'Hyderabad', 'Laptop', 75000, '2026-08-01'),
(2, 'Priya', 'Bangalore', 'Phone', 45000, '2026-08-02'),
(3, 'Rahul', 'Chennai', 'Laptop', 65000, '2026-08-03'),
(4, 'Anita', 'Hyderabad', 'Tablet', 30000, '2026-08-04'),
(5, 'David', 'Mumbai', 'Phone', 55000, '2026-08-05'),
(6, 'Priya', 'Bangalore', 'Laptop', 80000, '2026-08-06');
