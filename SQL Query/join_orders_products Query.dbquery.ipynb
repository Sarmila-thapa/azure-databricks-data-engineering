-- %%
SELECT 
    o.order_id, 
    o.customer_name, 
    o.city, 
    o.product, 
    p.category, 
    o.amount, 
    o.order_date
FROM sales_catalog.sales.orders o
JOIN sales_catalog.sales.products p
    ON o.product = p.product_name;
