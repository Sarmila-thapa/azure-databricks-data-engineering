-- %%
CREATE TABLE IF NOT EXISTS sales_catalog.sales.orders (
    order_id BIGINT,
    customer_name STRING,
    city STRING,
    product STRING,
    amount DECIMAL(10,2),
    order_date DATE
)
USING DELTA;
