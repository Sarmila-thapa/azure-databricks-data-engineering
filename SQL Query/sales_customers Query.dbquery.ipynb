-- %%
-- Create the customers table with the requested schema modifications
CREATE TABLE IF NOT EXISTS sales_catalog.sales.customers (
    customer_id BIGINT,
    order_id BIGINT,
    product_id BIGINT,
    email STRING,
    phone_number STRING
)
USING DELTA;

-- Insert sample data matching the customer IDs, orders, and products
INSERT INTO sales_catalog.sales.customers
VALUES
(1, 1, 1, 'john@example.com', '+91-9876543210'),
(2, 2, 2, 'priya@example.com', '+91-9876543211'),
(3, 3, 1, 'rahul@example.com', '+91-9876543212'),
(4, 4, 3, 'anita@example.com', '+91-9876543213'),
(5, 5, 2, 'david@example.com', '+91-9876543214');
