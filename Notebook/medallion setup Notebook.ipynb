# %%
# %sql
SELECT current_catalog()

# %%
# %sql
use catalog sales_new_catalog

# %%
# %sql
SELECT current_catalog()

# %%
# %sql
use catalog sales_new_catalog

# %%
# %sql
CREATE SCHEMA  IF NOT EXISTS  bronze
MANAGED LOCATION 'abfss://workshop@sarmila01.dfs.core.windows.net/Bronze/';

CREATE SCHEMA  IF NOT EXISTS  silver
MANAGED LOCATION 'abfss://workshop@sarmila01.dfs.core.windows.net/Silver/';

CREATE SCHEMA  IF NOT EXISTS  gold
MANAGED LOCATION 'abfss://workshop@sarmila01.dfs.core.windows.net/Gold/';

# %%
# %sql
CREATE  EXTERNAL  VOLUME  IF NOT EXISTS  landing
    LOCATION 'abfss://workshop@sarmila01.dfs.core.windows.net/Landing/'

# %%
landing_df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfss://workshop@sarmila01.dfs.core.windows.net/Landing/")

display(landing_df)
