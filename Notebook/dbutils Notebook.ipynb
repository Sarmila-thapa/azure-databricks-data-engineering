# %%
dbutils.fs.ls("abfss://workshop@sarmila01.dfs.core.windows.net/")

# %%
dbutils.fs.head("abfss://workshop@sarmila01.dfs.core.windows.net/healthexp.csv")

# %%
dbutils.fs.put("abfss://workshop@sarmila01.dfs.core.windows.net/healthexp.csv", 'Sample data', overwrite=True)

# %%
dbutils.fs.mkdirs("abfss://workshop@sarmila01.dfs.core.windows.net/healthexp")
