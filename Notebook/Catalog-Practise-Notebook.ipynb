# %%
# %sql
use catalog saru01

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS saru01.demo_schema;

# %%
data = [
    (101, "Ravi", "Hyderabad", 30),
    (102, "Sita", "Chennai", 25),
    (103, "John", "Bangalore", 35),
    (104, "Priya", "Mumbai", 28)
]

columns = ["customer_id", "customer_name", "city", "age"]

df = spark.createDataFrame(data, columns)

df.show()
df.printSchema()

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("saru01.demo_schema.customers")

# %%
# %sql
DESCRIBE detail saru01.demo_schema.customers;

# %%
# %sql
DROP TABLE IF EXISTS saru01.demo_schema.customers;

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(
        "saru01.demo_schema.customers",
        path="abfss://workshop@sarmila01.dfs.core.windows.net/DemoSamples/customers/"
    )

# %%
# %sql
select * from saru01.demo_schema.customers

# %%
# %sql
INSERT INTO saru01.demo_schema.customers
(customer_id, customer_name, city, age)
VALUES
(106, 'Kiran', 'Delhi', 29),
(107, 'Meena', 'Kochi', 31),
(108, 'Vijay', 'Mumbai', 27);

# %%
# %sql
DESCRIBE HISTORY saru01.demo_schema.customers

# %%
# %sql
select * from saru01.demo_schema.customers

# %%
# %sql
UPDATE saru01.demo_schema.customers
SET city = 'Hyderabad'
WHERE customer_id = 104;

# %%
# %sql
DESCRIBE HISTORY saru01.demo_schema.customers

# %%
# %sql
SELECT *
FROM saru01.demo_schema.customers VERSION AS OF 0;

# %%
# %sql
SELECT *
FROM saru01.demo_schema.customers VERSION AS OF 1

EXCEPT

SELECT *
FROM saru01.demo_schema.customers VERSION AS OF 2;

# %%
# %sql 
--RESTORE TABLE saru01.demo_schema.customers TO VERSION AS OF 0;

SELECT * FROM saru01.demo_schema.customers

# %%
# %sql
DESCRIBE HISTORY saru01.demo_schema.customers

# %%
# %sql
DESCRIBE HISTORY saru01.demo_schema.customers

# %%
# %sql
INSERT INTO saru01.demo_schema.customers
(customer_id, customer_name, city, age)
VALUES
(109, 'Aira', 'Delhi', 29),
(110, 'Hemala', 'Kochi', 31),
(111, 'Vijay', 'Mumbai', 27);

# %%
# %sql
select * from saru01.demo_schema.customers

# %%
# %sql
DESCRIBE HISTORY saru01.demo_schema.customers

# %%
# %sql
SELECT *
FROM saru01.demo_schema.customers VERSION AS OF 1

EXCEPT

SELECT *
FROM saru01.demo_schema.customers VERSION AS OF 2;

# %%
# %sql 
RESTORE TABLE saru01.demo_schema.customers TO VERSION AS OF 0;
